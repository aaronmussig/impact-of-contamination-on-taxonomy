# %%
import sys


sys.path.append("/Users/aaron/phd/impact-of-contamination-on-taxonomy")

# %%
from workflow.gunc_helper.aggregate_max_css_level_merged import AggregateMaxCssLevelMerged

# %%
DF_CSS = AggregateMaxCssLevelMerged().output().read_cached()
DF_CSS.head()
# Out:
# [19/12/2022 08:40:22] - 1.9MiB = /srv/home/uqamussi/projects/gunc-chimeras/output/gunc_helper/gunc_merged_max_css_level.h5 -> /tmp/gunc-cache/srv/home/uqamussi/projects/gunc-chimeras/output/gunc_helper/gunc_merged_max_css_level.h5
#                  n_genes_called  n_genes_mapped  n_contigs taxonomic_level  \
# gid
# GCA_000143435.1            2189            2110          4           genus
# GCA_000153745.1            2202            2165          2          family
# GCA_000155005.1            6879            6313         84           genus
# GCA_000161815.1            4499            4335          8           genus
# GCA_000166735.2            3414            3247        793           genus
#
#                  proportion_genes_retained_in_major_clades  \
# gid
# GCA_000143435.1                                       0.89
# GCA_000153745.1                                       0.92
# GCA_000155005.1                                       0.87
# ...

# %%
from workflow.external.gtdb_metadata import GtdbMetadataR207

DF_META = GtdbMetadataR207().output().read_cached()
DF_META.head()
# Out:
# [19/12/2022 08:40:52] - 40.6MiB = /srv/home/uqamussi/projects/gunc-chimeras/output/external/gtdb_r207_metadata.h5 -> /tmp/gunc-cache/srv/home/uqamussi/projects/gunc-chimeras/output/external/gtdb_r207_metadata.h5
#                  ambiguous_bases  checkm_completeness  checkm_contamination  \
# gid
# GCA_000006155.2             1916                93.12                   0.0
# GCA_000007325.1                1                99.95                   0.0
# GCA_000007385.1                0                99.82                   0.0
# GCA_000008085.1                0                73.13                   0.0
# GCA_000008885.1                0               100.00                   0.0
#
#                  checkm_marker_count             checkm_marker_lineage  \
# gid
# GCA_000006155.2                 1171              g__Bacillus (UID902)
# GCA_000007325.1                  149             k__Bacteria (UID2329)
# GCA_000007385.1                  481  c__Gammaproteobacteria (UID4202)
# ...

# %%
df_meta_fail = DF_META[DF_META.index.isin(DF_CSS.index)]
print(len(df_meta_fail))
df_meta_fail.head()
# Out:
# 35723
#                  ambiguous_bases  checkm_completeness  checkm_contamination  \
# gid
# GCA_000143435.1             2503                99.48                  0.52
# GCA_000153745.1                0                94.58                  3.48
# GCA_000155005.1                0                98.81                  8.44
# GCA_000161815.1                0                99.08                  0.18
# GCA_000166735.2               33                95.81                  6.07
#
#                  checkm_marker_count            checkm_marker_lineage  \
# gid
# GCA_000143435.1                  350      o__Lactobacillales (UID374)
# GCA_000153745.1                  615    f__Rhodobacteraceae (UID3356)
# GCA_000155005.1                 1171  f__Enterobacteriaceae (UID5124)
# GCA_000161815.1                  625    f__Rhodobacteraceae (UID3375)
# GCA_000166735.2                  443     f__Leuconostocaceae (UID486)
#
# ...

# %%
df_meta_fail_low_contig = df_meta_fail[df_meta_fail['contig_count'] < 20]
print(len(df_meta_fail_low_contig))
df_meta_fail_low_contig.sort_values(by=['contig_count'], inplace=True)
df_meta_fail_low_contig.head()
# Out:
# 1745
# /var/folders/bp/jw5q113j0vj4pzdtdczxrltr0000gn/T/ipykernel_14243/160580778.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_meta_fail_low_contig.sort_values(by=['contig_count'], inplace=True)
#                  ambiguous_bases  checkm_completeness  checkm_contamination  \
# gid
# GCF_000048645.1              107               100.00                  0.19
# GCF_003717355.1                0               100.00                  0.07
# GCF_015223545.3                0                99.29                  0.66
# GCF_008632435.1                0                99.99                  0.86
# GCA_900205245.1                0               100.00                  0.17
#
#                  checkm_marker_count             checkm_marker_lineage  \
# gid
# ...

# %%
import seaborn as sns
sns.histplot(data=df_meta_fail_low_contig, x='contig_count')
# Out:
# <AxesSubplot: xlabel='contig_count', ylabel='Count'>
